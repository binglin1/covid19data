# %%
import pandas as pd

# %%
df_confirmed = pd.read_csv('time_series_covid19_confirmed_global_narrow.csv')
df_deaths    = pd.read_csv('time_series_covid19_deaths_global_narrow.csv')
df_recovered = pd.read_csv('time_series_covid19_recovered_global_narrow.csv')

# %%
df_confirmed
# Out:
#       Province/State Country/Region       Lat      Long        Date  \
# 0         #adm1+name  #country+name  #geo+lat  #geo+lon       #date
# 1                NaN    Afghanistan      33.0      65.0  2020-04-09
# 2                NaN    Afghanistan      33.0      65.0  2020-04-08
# 3                NaN    Afghanistan      33.0      65.0  2020-04-07
# 4                NaN    Afghanistan      33.0      65.0  2020-04-06
# ...              ...            ...       ...       ...         ...
# 20773            NaN       Zimbabwe     -20.0      30.0  2020-01-26
# 20774            NaN       Zimbabwe     -20.0      30.0  2020-01-25
# 20775            NaN       Zimbabwe     -20.0      30.0  2020-01-24
# 20776            NaN       Zimbabwe     -20.0      30.0  2020-01-23
# 20777            NaN       Zimbabwe     -20.0      30.0  2020-01-22
#
#                           Confirmed
# 0      #affected+infected+value+num
# 1                               484
# 2                               444
# ...

# %%
df_deaths
# Out:
#       Province/State Country/Region       Lat      Long        Date  \
# 0         #adm1+name  #country+name  #geo+lat  #geo+lon       #date
# 1                NaN    Afghanistan      33.0      65.0  2020-04-09
# 2                NaN    Afghanistan      33.0      65.0  2020-04-08
# 3                NaN    Afghanistan      33.0      65.0  2020-04-07
# 4                NaN    Afghanistan      33.0      65.0  2020-04-06
# ...              ...            ...       ...       ...         ...
# 20773            NaN       Zimbabwe     -20.0      30.0  2020-01-26
# 20774            NaN       Zimbabwe     -20.0      30.0  2020-01-25
# 20775            NaN       Zimbabwe     -20.0      30.0  2020-01-24
# 20776            NaN       Zimbabwe     -20.0      30.0  2020-01-23
# 20777            NaN       Zimbabwe     -20.0      30.0  2020-01-22
#
#                              Deaths
# 0      #affected+infected+value+num
# 1                                15
# 2                                14
# ...

# %%
df_recovered
# Out:
#       Province/State Country/Region       Lat      Long        Date  \
# 0         #adm1+name  #country+name  #geo+lat  #geo+lon       #date
# 1                NaN    Afghanistan      33.0      65.0  2020-04-09
# 2                NaN    Afghanistan      33.0      65.0  2020-04-08
# 3                NaN    Afghanistan      33.0      65.0  2020-04-07
# 4                NaN    Afghanistan      33.0      65.0  2020-04-06
# ...              ...            ...       ...       ...         ...
# 19667            NaN       Zimbabwe     -20.0      30.0  2020-01-26
# 19668            NaN       Zimbabwe     -20.0      30.0  2020-01-25
# 19669            NaN       Zimbabwe     -20.0      30.0  2020-01-24
# 19670            NaN       Zimbabwe     -20.0      30.0  2020-01-23
# 19671            NaN       Zimbabwe     -20.0      30.0  2020-01-22
#
#                           Recovered
# 0      #affected+infected+value+num
# 1                                32
# 2                                29
# ...

# %%
df_confirmed.drop(['ISO 3166-1 Alpha 3-Codes', 'Region Code', 'Sub-region Code','Intermediate Region Code'], axis=1, inplace=True)
df_confirmed = df_confirmed.rename(columns={'Value':'Confirmed'})

df_deaths.drop(['ISO 3166-1 Alpha 3-Codes', 'Region Code', 'Sub-region Code','Intermediate Region Code'], axis=1, inplace=True)
df_deaths = df_deaths.rename(columns={'Value':'Deaths'})

df_recovered.drop(['ISO 3166-1 Alpha 3-Codes', 'Region Code', 'Sub-region Code','Intermediate Region Code'], axis=1, inplace=True)
df_recovered = df_recovered.rename(columns={'Value':'Recovered'})

# %%
df = pd.concat([df_confirmed, df_deaths, df_recovered], axis=1, join='outer')

# %%
df = df.loc[:,~df.columns.duplicated()]

# %%
df
# Out:
#       Province/State Country/Region       Lat      Long        Date  \
# 0         #adm1+name  #country+name  #geo+lat  #geo+lon       #date
# 1                NaN    Afghanistan      33.0      65.0  2020-04-09
# 2                NaN    Afghanistan      33.0      65.0  2020-04-08
# 3                NaN    Afghanistan      33.0      65.0  2020-04-07
# 4                NaN    Afghanistan      33.0      65.0  2020-04-06
# ...              ...            ...       ...       ...         ...
# 20773            NaN       Zimbabwe     -20.0      30.0  2020-01-26
# 20774            NaN       Zimbabwe     -20.0      30.0  2020-01-25
# 20775            NaN       Zimbabwe     -20.0      30.0  2020-01-24
# 20776            NaN       Zimbabwe     -20.0      30.0  2020-01-23
# 20777            NaN       Zimbabwe     -20.0      30.0  2020-01-22
#
#                           Confirmed                        Deaths  \
# 0      #affected+infected+value+num  #affected+infected+value+num
# ...
